# %%
from wyvern.layout import planform_stats, planform_span_stations

from wyvern.data import PLANFORM_CONFIGS

planform_stats(PLANFORM_CONFIGS["NF-844-D"])
# Out:
#           overall_area  overall_span  overall_mean_aerodynamic_chord  \
# NF-844-D       0.56595        1700.0                      413.538298
#
#           overall_aspect_ratio  overall_centroid  wing_span  wing_half_area  \
# NF-844-D              5.106458         474.18116      665.0          0.1729
#
#           wing_mean_aerodynamic_chord  wing_aspect_ratio  wing_centroid  \
# NF-844-D                   285.128205           5.115385     515.077099
#
#           centerbody_span  centerbody_half_area  \
# NF-844-D            185.0              0.110075
#
#           centerbody_mean_aerodynamic_chord  centerbody_aspect_ratio  \
# NF-844-D                         615.238095                 0.621849
#
#           centerbody_centroid
# NF-844-D           409.943978

# %%
planform_span_stations(PLANFORM_CONFIGS["NF-844-D"])
# Out:
#                         Y         XLE       chord         XTE  hinge_line
# center                0.0    0.000000  780.000000  780.000000         NaN
# midbody              92.5  120.000000  600.000000  720.000000         NaN
# wing_root           185.0  215.000000  400.000000  615.000000         NaN
# ctrl_surface_start  600.0  454.600362  225.263158  679.863520  612.284572
# ctrl_surface_end    800.0  570.070416  141.052632  711.123047  668.807258
# wing_tip            850.0  598.937929  120.000000  718.937929         NaN
